# %% [markdown]
# ## Binary Classification
# https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data

# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
# !pip install torch

# %%
import pandas as pd
import numpy as np

import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %%
print(np.__version__)
# Out:
# 1.24.1

# %%
print(torch.__version__)
# Out:
# 2.0.1+cpu

# %%
columns = ['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']

# %%
wine_data = pd.read_csv('data/Wine.csv', names=columns)
wine_data.sample(5)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 148      3    13.32        3.24  2.38               21.5         92
# 166      3    13.45        3.70  2.60               23.0        111
# 173      3    13.71        5.65  2.45               20.5         95
# 15       1    13.63        1.81  2.70               17.2        112
# 17       1    13.83        1.57  2.62               20.0        115
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 148           1.93        0.76                  0.45             1.25
# 166           1.70        0.92                  0.43             1.46
# 173           1.68        0.61                  0.52             1.06
# 15            2.85        2.91                  0.30             1.46
# 17            2.95        3.40                  0.40             1.72
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 148             8.42  0.55                          1.62      650
# 166            10.68  0.85                          1.56      695
# 173             7.70  0.64                          1.74      740
# 15              7.30  1.28                          2.88     1310
# 17              6.60  1.13                          2.57     1130

# %%
wine_data.shape
# Out:
# (178, 14)

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# #### Cleaning the data
# * Removing all the records having NaN values
# * Convert target values to number using label encoding

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()

wine_data['Class'] = le.fit_transform(wine_data['Class'])

wine_data.sample(10)
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 83       1    13.05        3.86  2.32               22.5         85
# 138      2    13.49        3.59  2.19               19.5         88
# 29       0    14.02        1.68  2.21               16.0         96
# 67       1    12.37        1.17  1.92               19.6         78
# 131      2    12.88        2.99  2.40               20.0        104
# 56       0    14.22        1.70  2.30               16.3        118
# 176      2    13.17        2.59  2.37               20.0        120
# 153      2    13.23        3.30  2.28               18.5         98
# 97       1    12.29        1.41  1.98               16.0         85
# 17       0    13.83        1.57  2.62               20.0        115
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 83            1.65        1.59                  0.61             1.62
# 138           1.62        0.48                  0.58             0.88
# 29            2.65        2.33                  0.26             1.98
# 67            2.11        2.00                  0.27             1.04
# 131           1.30        1.22                  0.24             0.83
# 56            3.20        3.00                  0.26             2.03
# 176           1.65        0.68                  0.53             1.46
# 153           1.80        0.83                  0.61             1.87
# 97            2.55        2.50                  0.29             1.77
# 17            2.95        3.40                  0.40             1.72
#
#      Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 83              4.80  0.84                          2.01      515
# 138             5.70  0.81                          1.82      580
# 29              4.70  1.04                          3.59     1035
# 67              4.68  1.12                          3.48      510
# 131             5.40  0.74                          1.42      530
# 56              6.38  0.94                          3.31      970
# 176             9.30  0.60                          1.62      840
# 153            10.52  0.56                          1.51      675
# 97              2.90  1.23                          2.74      428
# 17              6.60  1.13                          2.57     1130

# %%
wine_data.to_csv('data/wine_data.csv', index = False)

# %% [markdown]
# #### Collecting Features
# * Create training and test data using train_test_split

# %%
wine_features = wine_data.drop('Class', axis = 1)
wine_features.sample(5)
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 26     13.39        1.77  2.62               16.1         93           2.85
# 63     12.37        1.13  2.16               19.0         87           3.50
# 154    12.58        1.29  2.10               20.0        103           1.48
# 174    13.40        3.91  2.48               23.0        102           1.80
# 150    13.50        3.12  2.62               24.0        123           1.40
#
#      Flavanoids  Nonflavanoid phenols  Proanthocyanins  Color intensity   Hue  \
# 26         2.94                  0.34             1.45             4.80  0.92
# 63         3.10                  0.19             1.87             4.45  1.22
# 154        0.58                  0.53             1.40             7.60  0.58
# 174        0.75                  0.43             1.41             7.30  0.70
# 150        1.57                  0.22             1.25             8.60  0.59
#
#      OD280/OD315 of diluted wines  Proline
# 26                           3.22     1195
# 63                           2.87      420
# 154                          1.55      640
# 174                          1.56      750
# 150                          1.30      500

# %%
wine_target = wine_data[['Class']]
wine_target.sample(5)
# Out:
#      Class
# 108      1
# 9        0
# 139      2
# 56       0
# 157      2

# %%
from sklearn.model_selection import train_test_split

X_train, x_test, Y_train, y_test = train_test_split(wine_features,
                                                    wine_target,
                                                    test_size=0.4,
                                                    random_state=0)

# %%
X_train.shape, Y_train.shape
# Out:
# ((106, 13), (106, 1))

# %% [markdown]
# #### Convert data into tensors

# %%
Xtrain_ = torch.from_numpy(X_train.values).float()
Xtest_ = torch.from_numpy(x_test.values).float()

# %%
Xtrain_.shape
# Out:
# torch.Size([106, 13])

# %% [markdown]
# Y parameters have shape 106 X 1 but we need those in shape 1 X 106<br>
# Our loss function doesnt support multi-target, our target should be 1D Tensor
# i.e 1 row containing all the labels<br>
#
# <b>view: </b>with view we reshape the tensor <br>
# view with -1<br>
# If there is any situation that you don't know how many columns you want but are sure of the number of rows then you can mention it as -1, or vice-versa (You can extend this to tensors with more dimensions. Only one of the axis value can be -1).

# %%
Ytrain_ = torch.from_numpy(Y_train.values).view(1,-1)[0]
Ytest_ = torch.from_numpy(y_test.values).view(1,-1)[0]

# %%
Ytrain_.shape
# Out:
# torch.Size([106])

# %% [markdown]
# ## Creating a classifier

# %% [markdown]
# we have 13 features therefore input size is 13 and we want 3 discrete outputs

# %%
input_size = 13
output_size = 3
hidden_size = 100

# %% [markdown]
# #### Define a neural network class from which to create our model
#
# We create a class named Net which inherits nn.Module(Base class for all neural network modules.)<br>
#
# <b>super :</b> This is calling the \__init__() method of the parent class(nn.Module)
#
# <b>fc1 to fc3 :</b>  Applies a linear transformation to the incoming data: y=Wx+b<br>
# Parameters :<br>
# in_features – size of each input sample<br>
# out_features – size of each output sample<br>
# bias – If set to False, the layer will not learn an additive bias. Default: True<br>
#
# <b>Sigmoid : </b>Applies the element-wise function Sigmoid(x)= 1 / (1+exp(−x))
#
# <b>log_softmax :</b>
# Softmax applies the Softmax() function to an n-dimensional input Tensor rescaling them so that the elements of the n-dimensional output Tensor lie in the range (0,1) and sum to 1<br>
# While mathematically equivalent to log(softmax(x)), doing these two operations separately is slower, and numerically unstable. This function uses an alternative formulation to compute the output and gradient correctly.<br>
# Parameters:<br>
# dim(int) – A dimension along which Softmax will be computed (so every slice along dim will sum to 1).

# %%
class Net(nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        X = torch.sigmoid((self.fc1(X)))
        X = torch.sigmoid(self.fc2(X))
        X = self.fc3(X)

        return F.log_softmax(X, dim=-1)

# %%
model = Net()

# %% [markdown]
# #### Defining optimizer and loss function

# %%
import torch.optim as optim

optimizer = optim.Adam(model.parameters(), lr = 0.01)

loss_fn = nn.NLLLoss()

# %% [markdown]
# #### Training the model

# %% [markdown]
# Optimizer.zero_grad:
# * Before the backward pass, use the optimizer object to zero all of the gradients for the variables it will update (which are the learnable weights of the model)
#
# Foward Pass:
# * Predicting Y with input data X
#
# Finding training Loss:
# * Finding difference between Y_train_tensor and Y_pred using NLLLoss() function defined above
#
#
# Back Propogation:
# * back propogation is done by simply loss.backward() function
#
# Working on test data<br>
# predicting Y with X test data<br>
# Finding test loss same as training loss, but we will not back propogate this loss<br>
#
# Finding accuracy
# * we used .eq() function which computes element-wise equality
# * returns 1 if element is equal else 0 (Hence its summation will give us total correct predictions)
#
# We append all data in the form of list per epoch so that it will be easier for us to plot graphs

# %%
epochs = 1000

for epoch in range(epochs):

    optimizer.zero_grad()
    Ypred = model(Xtrain_)

    loss = loss_fn(Ypred , Ytrain_)
    loss.backward()

    optimizer.step()
        
    if epoch % 100 == 0:
        print ('Epoch', epoch, 'loss', loss.item())
# Out:
# Epoch 0 loss 1.1445715427398682
# Epoch 100 loss 0.442806214094162
# Epoch 200 loss 0.06015758588910103
# Epoch 300 loss 0.05101180821657181
# Epoch 400 loss 0.04862520471215248
# Epoch 500 loss 0.047397345304489136
# Epoch 600 loss 0.046599019318819046
# Epoch 700 loss 0.04599539190530777
# Epoch 800 loss 0.04547502100467682
# Epoch 900 loss 0.044991228729486465

# %% [markdown]
# ## Saving the model
# * saves and loads the entire model, all the intermediate variables as well, like intermediate outputs for back propagation use.

# %%
list(model.parameters())
# Out:
# [Parameter containing:
#  tensor([[-0.2623, -0.1539,  0.1760,  ..., -0.2537,  0.1115, -0.2060],
#          [-0.0221,  0.1724, -0.1271,  ...,  0.1819,  0.0640,  0.1022],
#          [-0.1655,  0.2747,  0.1801,  ...,  0.1069, -0.2559, -0.2362],
#          ...,
#          [ 0.0056,  0.2334, -0.2648,  ...,  0.1256, -0.2578, -0.0056],
#          [ 0.0960, -0.0973, -0.1034,  ...,  0.0225,  0.2414,  0.2521],
#          [-0.1915, -0.2479, -0.2676,  ..., -0.1850, -0.2333, -0.0310]],
#         requires_grad=True), Parameter containing:
#  tensor([-4.2211e-02, -1.7053e-01, -4.5946e-03, -1.6043e-01,  2.6865e-01,
#          -8.4923e-01,  2.4748e-01, -2.7346e-01,  7.0205e-03, -1.6623e-01,
#           2.7120e-01,  1.0300e-02, -2.6202e-01, -1.5330e-01,  1.4735e-01,
#           4.2576e-04, -6.5529e-02,  8.1007e-02,  6.9867e-02, -2.5786e-01,
#           2.7681e-01,  1.4196e-01, -2.3173e-01, -2.2348e-02,  5.7680e-02,
#          -4.2618e-02,  9.2887e-02,  1.1920e-01, -2.9528e-02,  2.8631e-01,
#           6.4100e-02,  1.6135e-01,  2.1620e-01, -1.5104e-01,  2.3946e-01,
#          -1.7450e-01,  2.6338e-01, -1.6863e-01,  5.1831e-02, -8.7004e-02,
#          -2.7408e-01,  2.3330e-01,  3.8788e-02, -2.4225e-01,  1.4593e-01,
#           1.8848e-01, -1.1409e-01, -1.6595e-02,  6.8212e-02, -2.2282e-01,
#           1.8434e-01, -1.6997e-01,  1.0441e-03, -1.9769e-01,  9.3669e-02,
#          -2.6254e-01,  2.6969e-01,  8.3796e-02,  3.3525e-02, -1.3227e-01,
#          -8.6143e-03,  9.5849e-02, -1.2828e-01,  2.1303e-01, -1.9637e-01,
#          -2.2209e-01, -5.0217e-02,  8.5650e-02,  3.6779e-04, -1.2463e-01,
#           1.0171e-01, -1.7294e-01,  1.6010e-01, -1.8025e-01, -1.2732e-02,
#          -6.0980e-01,  5.2198e-02,  2.4347e-01, -1.4568e-01,  2.4014e-01,
#           2.8265e-01, -1.1670e-01,  1.7578e-01,  2.5451e-01,  8.0800e-02,
#           7.9553e-02, -2.3865e-01, -1.4916e-01, -5.8081e-02,  2.0411e-01,
#          -8.8814e-02,  1.0466e-01, -1.2054e-01, -2.1207e-01,  1.4572e-01,
#          -2.7483e-01,  4.5574e-01,  1.6254e-02,  5.3643e-02,  9.1463e-02],
#         requires_grad=True), Parameter containing:
#  tensor([[ 0.0735, -0.0661, -0.0657,  ..., -0.0864, -0.0446, -0.0346],
#          [ 0.0182,  0.0431,  0.0324,  ..., -0.0352,  0.0339, -0.0474],
#          [ 0.0238,  0.0579, -0.0926,  ...,  0.0627,  0.0652,  0.0889],
#          ...,
#          [ 0.0217, -0.0168, -0.0711,  ...,  0.0755, -0.0236, -0.0849],
#          [ 0.0220, -0.0421,  0.0518,  ...,  0.0903,  0.0390,  0.0124],
#          [-0.0776,  0.0931, -0.0567,  ..., -0.0026,  0.0113,  0.0134]],
#         requires_grad=True), Parameter containing:
#  tensor([ 0.0067, -0.0958,  0.0332,  0.0179, -0.0164, -0.0497, -0.0471, -0.0019,
#           0.0397,  0.0572,  0.0270,  0.0190,  0.0330,  0.0537,  0.0727,  0.1168,
#           0.0361,  0.0483,  0.0338, -0.0894, -0.1034,  0.0460, -0.0691,  0.0944,
#          -0.1231, -0.0615,  0.0754,  0.0592,  0.0350,  0.0246, -0.0490, -0.0564,
#           0.0848, -0.1106, -0.0714,  0.0274, -0.1058, -0.0693,  0.0969,  0.1019,
#          -0.0700, -0.0906,  0.0524,  0.0520, -0.0181,  0.0498,  0.0138, -0.0176,
#          -0.0378,  0.0873,  0.0594,  0.0346, -0.0004, -0.0190, -0.0792,  0.0136,
#           0.0638, -0.1183, -0.0796,  0.0604,  0.0965,  0.0430,  0.0645,  0.0330,
#          -0.0717, -0.0997, -0.0538,  0.0091,  0.0599,  0.1030, -0.0925,  0.0539,
#          -0.0951,  0.0800, -0.0607, -0.0402,  0.0450, -0.0749, -0.0416,  0.0493,
#          -0.0253,  0.0684,  0.0723, -0.0484,  0.0974, -0.0898,  0.0117, -0.0047,
#          -0.0028,  0.0526,  0.0085,  0.1213,  0.0168,  0.0015, -0.0026,  0.0887,
#           0.0005,  0.0621, -0.0405, -0.0837], requires_grad=True), Parameter containing:
#  tensor([[ 2.9830e-01, -3.0610e-01, -2.8284e-01,  3.4242e-01, -5.7549e-01,
#           -7.7859e-02, -1.8198e-01, -6.4487e-01,  3.1639e-01, -3.7888e-01,
#           -3.3320e-01,  2.0258e-01, -2.4544e-01,  3.4164e-01,  3.9911e-01,
#            3.1000e-01,  4.3946e-01,  2.1656e-01,  3.4150e-01,  1.8528e-01,
#           -1.5494e-01,  4.9742e-02,  3.6166e-01,  2.7686e-01,  2.2958e-02,
#           -2.6709e-01, -1.5074e-01,  3.6029e-01,  4.3838e-01,  3.4473e-01,
#            4.4540e-01,  3.2250e-01,  1.4130e-01, -2.7758e-01,  2.8577e-01,
#            4.8782e-01, -2.1311e-01, -2.4107e-01,  7.4919e-02, -4.3170e-01,
#            4.1985e-01,  1.6216e-01, -3.0575e-01, -2.8728e-01,  3.4483e-01,
#            3.2624e-01,  2.1842e-01, -3.2715e-01, -3.4905e-01,  1.4540e-02,
#           -1.6237e-01, -5.1471e-01, -3.8677e-01, -2.5011e-01,  2.7114e-01,
#            1.9321e-01,  3.0896e-01, -1.7097e-01,  4.0251e-01, -2.4049e-01,
#            2.0123e-01, -3.4840e-01, -1.7899e-01,  1.0377e-02,  3.5637e-01,
#           -2.6583e-01, -3.7634e-01, -2.8140e-01,  2.4274e-01,  2.4651e-01,
#            1.3749e-01,  1.1804e-01,  5.8583e-01,  3.2359e-01,  4.1293e-01,
#            2.6822e-01, -4.1113e-01,  1.3353e-01, -2.0017e-01, -4.9124e-01,
#            3.7102e-01, -2.6448e-01,  2.1279e-01, -1.7120e-01,  1.1661e-01,
#            4.9857e-01,  1.9419e-01, -2.4010e-01,  4.4822e-01, -1.5709e-01,
#           -3.8960e-01,  3.4320e-01, -4.0097e-01,  4.2603e-01, -1.9059e-01,
#            3.2779e-01,  1.6110e-01,  2.1459e-01, -4.8673e-01,  2.7141e-01],
#          [-3.3781e-01,  2.8861e-01,  1.2243e-01, -2.8129e-01, -3.3588e-01,
#            5.1445e-01,  2.5023e-01, -3.4746e-01,  1.3097e-01, -1.6776e-01,
#            9.6723e-02, -2.3292e-01,  2.8581e-01, -1.2959e-01, -2.1845e-01,
#           -2.8896e-01,  6.2629e-02, -4.0824e-01, -1.0035e-02, -2.9675e-01,
#            2.7838e-01, -2.9245e-01, -8.7699e-02, -3.4833e-01,  2.8822e-01,
#            2.0141e-01,  3.2580e-01, -1.4045e-01, -3.2590e-01, -2.2835e-01,
#           -1.8392e-01, -3.3078e-01, -2.1759e-01,  2.3707e-01, -3.6184e-01,
#            1.1399e-01,  2.2812e-01, -4.0872e-01, -3.0572e-01, -1.4341e-01,
#            4.3576e-03, -3.0178e-01,  2.7401e-01,  4.5176e-02, -2.3409e-01,
#           -2.9185e-01, -3.4811e-01, -2.9816e-01,  8.2380e-02, -3.7380e-01,
#            2.0697e-01,  2.0709e-02, -9.1186e-02,  2.3906e-01,  1.8507e-01,
#            1.4242e-01, -2.2271e-01,  2.3503e-01,  3.6882e-02,  2.1912e-01,
#           -2.7731e-01, -7.9620e-02,  2.2974e-01, -5.2278e-01, -2.5009e-01,
#            2.3543e-01,  1.1454e-01,  2.0308e-01, -2.9425e-01, -3.0976e-01,
#            2.9887e-01, -3.6482e-01, -3.0209e-01, -1.6384e-01, -3.7071e-01,
#           -2.1146e-01, -2.4368e-01,  3.7207e-01,  3.3486e-01,  2.4574e-01,
#            2.4605e-01,  9.4864e-02,  6.9686e-01,  2.8006e-01, -3.5096e-01,
#            1.4002e-01, -3.7232e-01,  1.8874e-01, -9.4840e-02,  2.7294e-01,
#           -5.0315e-02, -3.0335e-01, -5.2656e-02, -3.8162e-01,  2.0903e-01,
#           -3.0093e-01,  2.5467e-01, -3.3197e-01, -2.7032e-01, -1.9416e-01],
#          [-9.5342e-02,  8.3943e-02,  2.7255e-01, -4.0323e-01,  8.6408e-01,
#           -6.6677e-01, -5.8820e-04,  8.6645e-01, -4.0725e-01,  8.6540e-01,
#            1.4151e-01,  1.5521e-01, -2.0232e-02, -2.0492e-01, -1.6324e-01,
#           -2.1647e-01, -5.2463e-01,  1.9040e-01, -3.8929e-01,  2.0271e-01,
#           -1.1123e-01,  2.8107e-01, -4.8475e-01,  5.1757e-02, -4.2991e-01,
#            1.5987e-01, -1.1450e-01, -5.0648e-01, -1.8060e-01, -3.3809e-01,
#           -3.6216e-01,  1.7950e-01,  2.7081e-01,  2.7266e-01, -6.8266e-02,
#           -7.7882e-01,  1.5815e-01,  8.4399e-01,  1.1025e-02,  6.8173e-01,
#           -6.8932e-01,  1.6597e-01,  1.9606e-01,  3.4605e-01, -2.1150e-01,
#           -1.9703e-02,  1.4886e-01,  7.2325e-01,  2.2660e-01,  4.9450e-01,
#            2.2090e-04,  7.7008e-01,  5.1603e-01, -6.6218e-02, -7.4750e-01,
#           -7.1192e-01, -2.9365e-01,  7.5352e-02, -7.0754e-01,  1.3578e-01,
#            1.5422e-01,  6.4854e-01, -6.8963e-02,  3.7845e-01, -2.0611e-01,
#            2.2441e-01,  3.4403e-01,  1.3112e-01, -5.9370e-02,  2.2100e-01,
#           -7.3280e-01,  3.0845e-01, -8.9182e-01, -1.3935e-02, -2.3753e-01,
#           -9.7423e-02,  8.6710e-01, -5.7185e-01, -3.7683e-01,  3.9000e-01,
#           -9.3101e-01,  9.4151e-02, -9.7425e-01, -3.1611e-01,  2.7905e-01,
#           -8.4648e-01,  2.2292e-01,  5.6847e-02, -5.2720e-01,  1.0753e-01,
#            6.3571e-01, -1.9178e-01,  6.0691e-01, -1.4362e-01,  2.2260e-01,
#           -1.4193e-01, -7.3233e-01,  1.8493e-01,  7.7832e-01, -2.6565e-01]],
#         requires_grad=True), Parameter containing:
#  tensor([-0.0329,  0.0061, -0.0530], requires_grad=True)]

# %%
torch.save(model, 'models/classifier.pt')
# Out:
# /anaconda3/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type Net. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
# !ls models
# Out:
# classifier.pt

# %%
# !cat models/classifier.pt
# Out:
# ��
# little_endianq�X
# type_sizesq}q(XshortqKXintqKXlongqKuu.�(Xmoduleqc__main__
# Net
# _backendqctorch.nn.backends.thnn
# _get_thnn_function_backend
# ccollections
# OrderedDict
# q	)Rq
# _modulesqh	)Rq(Xfc1q(hctorch.nn.modules.linear
# Linear
# qXA/anaconda3/lib/python3.6/site-packages/torch/nn/modules/linear.pyqXQ	class Linear(Module):
#     r"""Applies a linear transformation to the incoming data: :math:`y = xA^T + b`
#
#     Args:
#         in_features: size of each input sample
#         out_features: size of each output sample
#         bias: If set to False, the layer will not learn an additive bias.
#             Default: ``True``
#
#     Shape:
#         - Input: :math:`(N, *, \text{in\_features})` where :math:`*` means any number of
#           additional dimensions
#         - Output: :math:`(N, *, \text{out\_features})` where all but the last dimension
#           are the same shape as the input.
#
#     Attributes:
#         weight: the learnable weights of the module of shape
#             :math:`(\text{out\_features}, \text{in\_features})`. The values are
#             initialized from :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})`, where
#             :math:`k = \frac{1}{\text{in\_features}}`
#         bias:   the learnable bias of the module of shape :math:`(\text{out\_features})`.
#                 If :attr:`bias` is ``True``, the values are initialized from
#                 :math:`\mathcal{U}(-\sqrt{k}, \sqrt{k})` where
#                 :math:`k = \frac{1}{\text{in\_features}}`
#
#     Examples::
#
#         >>> m = nn.Linear(20, 30)
#         >>> input = torch.randn(128, 20)
#         >>> output = m(input)
#         >>> print(output.size())
#         torch.Size([128, 30])
#     """
#     __constants__ = ['bias']
#
#     def __init__(self, in_features, out_features, bias=True):
#         super(Linear, self).__init__()
#         self.in_features = in_features
#         self.out_features = out_features
#         self.weight = Parameter(torch.Tensor(out_features, in_features))
#         if bias:
#             self.bias = Parameter(torch.Tensor(out_features))
#         else:
#             self.register_parameter('bias', None)
#         self.reset_parameters()
#
#     def reset_parameters(self):
#         init.kaiming_uniform_(self.weight, a=math.sqrt(5))
#         if self.bias is not None:
#             fan_in, _ = init._calculate_fan_in_and_fan_out(self.weight)
#             bound = 1 / math.sqrt(fan_in)
#             init.uniform_(self.bias, -bound, bound)
#
#     @weak_script_method
#     def forward(self, input):
#         return F.linear(input, self.weight, self.bias)
#
#     def extra_repr(self):
#         return 'in_features={}, out_features={}, bias={}'.format(
#             self.in_features, self.out_features, self.bias is not None
#         )
# h	)Rq (Xweightq!ctorch._utils
# _rebuild_parameter
# q"ctorch._utils
# _rebuild_tensor_v2
# q#((Xstorageq$ctorch
# FloatStorage
# h	)Rq~hh	)Rqhh	)Rq�hh	)Rq�hh	)Rq�hh	)Rq�hC�hDKdhEKubuhC�ub.�]q(X140717270305424qX140717270352864qX140717270357424qX140717270358560qX140717270359056qX140717270359344qe.:N��\���,4>��=�S��@0U>��M
# ���J>N�l>�灾lg�=�R����0>�%���D�H�>�|>�勾Dpj��I>!83��>:>���=h5�=l)����>�k8>bX>��k>�2=1�=
# >j�!>>,4�=�<���׽�mL�����C����,>�m\>��Y��X%�����Z>s��ۢ=0d���Kۼ27�fak>�nN>�M�=Qt>�i�J_�h}Q>��->����h��{%�0�̼���� �<C���+;����=�a>� >Z��'I�4>�M*>��8�^������=��>�W<HcK��^�,�=��i>0.���>�H�=�>��>�L<��{6=H>'S��4X>���=�{=��!>p�e�E�<�d�C�����@��;�����=�RK=j(-�F!s>`�<	R�>�%X>!ぽ����Z���T����;G��>)�ڽ4�)>ú*=C�>jo���%>��0>8P5�2
# ��h䐽�u�>U��>��Ƚ��\=p���<�="ZZ>�%��\W7���H>��u<��>�C2>��|>d�=
# .e>��~�V$A>������;>@W%>�A�>N* >p�D=#P6��7��
# �p!>�N}>��t������B�=
# ��[=�Q�=>�>&_���|.��ʀ�
# �`:w���->��M>��;��j���>�c�#h�>�(>�'��Mj>�d��*��L�>/�v���o�U���W>���=��ټ8[E=�h�=��> 1>���=���^>�:A��m�>�d3���K>���a�|X>�z��n>P@��n�>"�=?�o��E>�R�>0��
# �e�]B�����<���!ܦ>h�S=n��DO�=�DS>���=4�Ž�d�=�r��n.ݽ@��;/>�FV��}�"D���Z�b���FʾQ>\�����>·d?���>l�\?kY�����?z�?
# 1иtu�=��W�������d>�z��6>޳:>Z>���=�<���O7=�k�>�'T��U
# ?3t��ev����;��n>�������K.���5��ֽ��=,~��p���><�������=62ǽ2�ӽ��K�R\A>@S�=]�7�H�>>�Q�=��@�<
# :w>I�>D���}�����(�>�V��m�=��¼�,z�Ê<
# ��w=���n�(���d �,�9�.����qH$����>
# ���U=�Py>--�6�u>+��>,���3>�O�>`z�=��=�at������m�fQ>�㵽QV�=X���L(Y��8>D���3V�>P'�<��[=Q�='���=�j������ȣ�Wt��^8?ә|=�Ք�i��=�켰�<���=�@�;�=@�=i�=EH���p��c=e����޾-��͂���y�������x�P�@�z�;�%�=�鲾�����-���H'�=�Iv�H�W�3.<!��=uԞ=��G=M���	=��6<Y��=�6Ľ�`S�=��8< ��=�e=h�"<�:����=�R���;����=#��E<@4��k�b��='Y�=���=@�c��s���{�=mY�<�˃=��t=@���
# �½6�i<]X=H��;�^��R�������1W��v9e=���<2j=�.d=��ɽ�7��Z	��[���|�=�����}���<P�½�L�=�'Y<23=)=�}���=��淼�h�����<�W��`�=ӯ;�Zn�����y7��-�>c����D9Qн&4�=	��;��=,F�������=G�W�v=�x���Tm�.O��Xa��s��
# �=�oۼ�:g?�<�)�
# =PBB����<>�l=����O�=��l=��X��`�=�8ͽ�G����</�=�S��`:���P1��_�Y���,�S�}�׽�#2=N��:
# =慏?��T��赽����/1=囕�B�2=3�:W����z��������=�e��o�@�:�h=Id��}�=NKd==�=���=���=���=�"<>��R=���=}�<�m��=����䒽'�< �9�;��=��"��=��G��b=Z�<TQ]��ü#��=&?=���<�ʮ=��C�_����=u
# ���)ŽGq��!����D=iq�=-W�&6����<a��==b�=
# =yҕ����<�3�Yo�P�8�7u��{����ٌS�9�<w.�=�P.= S��N=��#���½�w�e��!��'�;�/�*��H#=�w�Jy���K=��U=m�=,s�<��=��=��=����=˚�0v�=�Q��ua�=�A�=�=~E=t;�?���џ|=�Eǽ/$�C#=��=��k�#%\=d�M?�
# <3�=Dƞ=^]�?�"Ž	螽�����t`���-$����=�s�;��H�����½���=��=5<�bG=n>F=���^�M�!��;`@=���<� 0������>�>=�=J4���ﺼ�=NS;=��$�4�@�T����j�>�AܼZ�1=�
# �<1p�mc���w=|q��n�=�Z���"<��=���;`a�z��b73=X
# ���(4;�$ü4bU��$��@�a��<�������=���=C���0��%F=`ǽhu=0�x<��==W˽r�r=2۽=G����=p�|<�M�`���K<�Ҁ��-�䬇�~��V=�	˾j�==���";�f~��#��[�;�-�=�tt<���=��Y��?�<���=`�m=4g��x���À�=���C�;;HQ�?�>���F���w='�6���~=ㄽkP�="H����&?[�p�Jڨ�Wݽ=
# �:�rd��wS=Vq�l<��
# ϼ�t��5$��<`�u�e���G�=�y�<N�M쉽��=�K�=V��>��T�1�Q���=M�=1�c��Yf=�;�=J1=XO�=Qa=��=�v=	d?�i�J<�v��D�����=��=T#�=�;�iľ=2rN=�K���<M{�=��.=�9=����M5�%����a���b(=]s2<X�u<�ۥ=xW2��|&��/ҽ��=�\�����<��_�8��q\�>���=�F½W�j�	'o�����$�C���9,���
# �>��ܼش(�m5��62ƽe��=�r�<ʁ��^�Z=:[
# <��;�f�����;Qɇ=��P=��*=�:K��=D�J������=V�.=���]M]��U���!
# <
# ���U?`��;��j��l�=W~<E���,���8
# ż="q
# ��6�=]*-�(=��[
# ���=R�u;9��=���=(?μ��=y\<�i=��4=�Fo��@8���[��)��ͅ�[�;=휋=%�?�d�=鞔>��M<��=�L�==�=
# =qQ�=,1ּn�ؼ��&��ݮ=vE�U恽(��=	��=�<�s,=��<=���<;C��̿@=���=��༒���Qg�=�9=�<I�Mj=��^=P�����C�� �0�ɻ``9���=��=��<z�a=zԄ=�����?�'=���>��K��Q����<�<Z+�<��=��ݼ�g)<��; �Y�[`���h(�m�<���ך�=���@������<?�3���X��<�v¼2g��o9d��tk��<3��K�W?���<��;E��=Zn�=�
# 6�=�i}=N����:�<�k=��=X�Y<�����9<BP@=Z �="U+=3�+����Go\��<;�;$���=
# ���Q��=��>3�˽�钿�̹�Z�8@�<QE=o73�`�f�
# Ħ���k��Ā=r���AM�Ʀ=��4���|<-e;�ѐ�=g����d�U3�e�ʽ��4=�ǽ�K=�I=�á�rﰼ֑���?쨥<f���Xv@<���=(���訩���*=�?�	Ȑ�p��<� !��^��
# ��=j��X��a��t��H�:�%�����>mj�a��?���0@{<�p���jO�|
# =
# �����@�A��Q��_�z=ʢ���58=����t����<�r�=e%��,<�<�j��F0�=����z-=��=�ͼO,@<E�=�b����;j3?=Hh��V�=��=Ѝ�=&�=w�b���;Ր=�W�=�Y�G�H���Թ�=i�=_��=�����s=��_�8N�=@$'�������]q?�%��Nѿ2f� ��<ۀ=;Ԛ=�Q=������v=~����>�=Z
# ��P��C��Qڟ<׋=�=Z�=�J{=��=t�徢Lk=G�?�g�&�Ct��`<`X�<,�|=_D?汚��r�DN�<��g�'��=�1��=�bv=S����0|�=��=(<[<�=;k���%���m���J�/�=@vp�,����=���<牢� #;b�g=`����jf=Q���� ]=�J<,���t=V�=���):�=Q8��F�<XHż>:;=�ڎ�:=�KE;��%=Fp����m���"�6d)��:�=i\=��<1���pU!��4;={��=����=(5�<�Q�=��;F'��A?�=|��<�!=�ܼ���=w�=Y[�<�Z����>9.�=�A�?�˓=�<»�&=~O�;�1��7�m��Ǽ[/C�jӵ�E'�=-��=������29'�mO��#�i���<�'��ɞ�
# ؼ�U=d=.H��z>��t��猽���< 5x���&=��#�v�mĝ���$<O��<S[7<�0P�=0=Ĵ�>ф�=�L=��R=x"r����<����U'��~x=�>ѿ���=��6�vn<��<)uk��L<��=
# _�>��H��:�<��g=o=�Ɛ=���`�:x���q�>��r=�=���<�kǽ�"��.H�4X����,.U��P=:jD=������=������=u���������oU=hM��3���P͆�6ũ���l<���=�q�<�mW���=�o�<sT�<��2z$=��=r�E=9h�=�
# ����;�'��x����<7|��|��,�<��Fl�͸�=@eY�� �9M�;�_���?3�:L=��O���I<R)����=$q����d��E=j-��'�=���o�Ƚ#܊=ū�?���=z��<Q�=h�����+j���g=3D{=L�2���ܽSǃ=xb�<�.�����=�~���ݽ�섽�Pǽ�m�;��o<>$
# =t��=��>@@L�[d��P31<�?9=�l<Ӯ���׿<�.%���>%�X���P=�e��!<��<�����S-�ѵ�=��s:l=��_r�=��c���F�'�<.A�<�E�\=����#�<��=��g�,g�<ycO=h*=[k�4n�=�h&=i	�=��޽!�ǻ�����l�=3�:�W�= Π�����S=�4p�<�"ۼA��={�һ� �=9u��
#  ����q�;v{�?2hC=f�����?�p=l>����=X�r�evԽ*$����t?�<%��O)�=���<sý��������,����?�|'��X���c�=��;=(�I=PnQ�Zˏ��D=��;?L���P�=Mǆ�~����l=�qɽ]_�c��6�]/b=��a=mQ���J��y/�=�肾���j�v=`a:;��Ļ����e��<�X+�ޒ<�s��n��=�����<�A`���1=��%=ze���?�M{��l�=/=�P��1B<TCD��ر�b����N=��}<�hY<
# �=�r�=c}}�@�2��7
# |=���?����I=ؕ�<0?�Y����w=�w����+=��w=Q�L<Ja�=� �<Bd=|#Q=��=�m�=n5<�%R�8CG=�$V�����Z����{�{��=�$�<��� T̻D���PB�:�3?������E�_��=�x2<��=(�f�R==;\=�(�=��-=�㣼G�=r�w=��<�E������ˊ� ���}e��M=F��=��`=���<B����u�<g<��ǽ�[��D=Ú�<E������>s=�1\���;��=v���3��D="����:Y���W��ֲ=
# �9�l_=�| ����=%C+=P"�= !�=�9=)�
# [<�eC�V���#ý"r��T��<怽��Y=&$=��=���<̐�,G����d���O�D	�=��=NԊ�5)�=\��<J6����=
# �;<Y��=W����F���'X?�N�;mdo�T주�AI=
# ���=�G!=���=�`�=��=�h��a�=U.ǽs]�;Pq���o�<�5���^�H��=�h����a=>��4�|�]�վ��<(=�!V;=2�<�u��5�=�>�=�!��=�n=,�̼���=;#�r<�����jN=�5�=�&=�k��%��)�=
# =�[=f�V��=(zǽ ��;C�i�鸣=ط��b'��B�<T��=[? �=r�m?�޻�)<!+6��%���}=��ۓ���R�֠�=n�=��=��<5��=�B�+����@=<nP�⊁��)���V=�7C=p��4^�<�*�=���;�Y=;B���5�?��(=�������=�+=�
# �<\\�ت�<x�i���
# =O�={}�=�j<؞�=Z�E��l�=�J�=�K\=��#=�N�=��;�(�=C�-�o��=��
# �w�,�����s5�?�=�n��T���Kƽnߑ=uB�=���z��@V���m1<���<��=\@�����=:.`=C±���ݼR���C
# �=�L=�d5�*��=<�n;�'񾃧p����p�7<�� =�&
# ��Lf����=�m��
# ��;��
# ��]�=��=5�x=V-=�r�<d��<审=Њ"�
# ����0ۅ;�!��kI��x%̽�c�<
# �=��n=��l=�۞=�n`j�;0����=h�X<�.��5�;�*�<S�o�܇:�Ӽi0�=tt�����zY�=s#˽�!�=��н��轡��=J}=Ay�=�輭�0�M,���5y�n�N���-=��I=��������|��/�=P�F?�Ľ/�=��<:?����==���6s˼U�=c�_����<�=�K��D��,�<�v����;�Z�=�Ȧ��W�=l�=I
# x��m��<�F�a���@F��R
# �����7L�=~EN��� <�;��=.�g=�L�XQ߼�舻c��=�=>"=Ѓ&���"=���;�8&�o]��
# ���n�=��F=+ߜ��
# ��X��<q.�xʽ�ɽ�w��m��=�A+�Ȃ��?C�\.h=���<�1�=�~�=�J�=N�6�
# :��Rn��)T��.)M=�
# F��	��|�z��oh=̣ӽ;===��n��"�<!P��gG�����:a���C�R� ^����u�3_ƽN�(=t�e��0J�dH=�g�������`=������<([< ��;h�H<^в�!��<M��;���;��M^�=NS�=5(4�"�ɽR϶�σ�=�<6��=?�=�= ?��29=H��<��b�
# ��:�g4���<?�z	=ʮ@[��=�H��Qx�=�=�=��6=(C�<�_�=�=[�&;d�
# =�=�@<&ڷ�$n��R:=0�˻z��W�<=�d�<է�:�*�=xs|="��Vs�=��f<Ooɽc�b=���D=�誼�ß<�i�=�sf���=뗦=����=�V����=��<y��=�r��$=�e'�u5�=�K�<q�L��7��w��=Š=]k�=�FJ=�{���oo��/����(���a=�����������D�-i�=�
# ��ȿ�X罽��[��eS=;�����f�=���>�_��3%<\$=�p��&G�<5O|�,{��EĽ���=zcJ=6QG=$f= �%�c�=෉��@���8���@�<�a����^̽U9����< �Ͻt�� ��0��V�	 =��q=!�=����8(�����@��.0�=z��MC�=���<6y���=���eY�� ف��
# Ak?
# �{�<2x�<8�������y��6#�=*b=�=@�����l���
# x=��4�������y<:�|���=G�=?�=]�r+=5=2�f=h�]���s�\�=�@=Т�� �A��[�=��e<�eټm���.�=Z�U=���=$�=.H����<vK'��		=귽�E2��%8���=�'=.�=+4<�����;���y���g��`܃;0��;�$�=*�<���=7���ʙ=��`�H}�=〱=���<�@��w{����
# ����b<��v=:��;��=�C�.k�=��5��\�Vh�vk�=Q=�q��]��B�����P=�Q������h���&h?����|�Z����vNQ=�֨��o8=�.�!�=8���|d�<i�d=+��=��k�(*=���4��.@l=[}��Z�<jY�<I[�W�Q�5�=\��<ѵ�=[r<���=߯�=��������]H=��=M���x�=�?��	ʼ��Q;hrY=
# Z�"~��#�,=Z�m�I[�=����kV��8|ǽ���<U�T����=��=�t���i�<��輹;�=[j�=!�<�S�=�ƹ�3f����@1����<`���,��K��=l/=��U�(!���<���R�:'Ž�(���gG�ؚ��|�$ޘ�6WI=xb*����=�չ=��<=�)�=�R�<z���mE<�{�=F_/=�k�}��8��˄�=�F?��BԺ��Ľ&b���o��;x?ԣ�<Ry=�9�=�V=^���j�W�6>�5]y=/�P���E=-�ƽPP�;é_�t0�<@�A��ќ�IG`=�.=���5=��}n=`�\��b=ʯ�><V�<
# =�`�=���=�VϽ�1�=
# ~���K=�[��{=�w�=`�W������R=�啼Arq=
# -<�~��I
# ���P����"'
# =�\= M��s6��;}�l,)�}1&��-��_[�=�u?(��<�������.]���>�Z�x���Ե=����(���T�b=���t��=������n�=�c��dE���7?�B�"֋=�р=:�J�iE�=���I�=�J<����'���+p���";=ǫ��?����=⼽c0����=π���@�A�����G=���f�>��ּm�|�P��;h+`=�^#=�$�G���W�m�ga�>�����<�
# =�L6��c�=�=���=`SP;Ѝ��K	<�f��>n*=�5�#�=�L۽��<3a�?�o�=G�˼�{t<L�<�c]<P�	<�ۢ�J7�=����n��Ď�U��C<'qc�8-��	;��=������]���kk�q�<�Ʊ�r8�=���>��˼���<~=��=[���@������=�+�>�ٛ�Tɏ�>�=zw!�4s��但�y9;�餽��B=�M<6�
# �@qa��2l�;�<��a{�=��˼���<�ԍ�B� =8�μz��;�l3=���nH�=!O�<i�ٻ�E<��'=��=Ejv<q��=�_<`�7�r=�d���V�<X�����)��=)�= ���4�<[���PbI��V�C�=��1?�DU<�����K�;
# �<'%��B=�QH=��:M�<��8
# /�ຨ���<j�=H�a<�\y�������i���ჽ�Ј=�-
# ��m�z�����ٔ�Y�=���<��=G���TR��t�ϼ�~��-y:{�к���=z=���,�:�S�=
# ��>���={	�=�^�������<�`_<#c���B�=><�ßp��X-=�B�=��a<u{��;E���q���2O=�ԍ���:?iٛ=�~��抣��S�=.}�<`��;�j=L^V��ѕ?�̇���-;d��<��<=V=8K���:���%=묇���o�"ᏽ"rc�Ԑ�<"������*R���=�w�==_=�U=��y=�.�����e��p�i��O=훁=9|�=�|�<�	���Ы�8?���M�C	�g(c���nř<$UƼ(w��������<j��<��%<�Ǳ��E��f��{���Ps�����;R�=�翽v��=�[�O`C=��Ϻ��9t��H����=�����K?=����b ���=l-��#�ݻ�˽���=[��=z��>�����(@���0�߻�q<�o=_H�=��'<`�S�zf��}Y=�̽�a��P�=m˼���Ђ=�Z�<
# %m����n���u˽7�ϼB�>=�j`��T=�А<zt� [ۼ� ��{$%=l&�=`.8���=�-=��=S����_e=3w��)�\�F�=v�����ƽ'#\=z�>j͹��"�,=U�J�L~�<� ��崽��=x��>㼳9�=��
# �=�$�K��}b=^�<���<����qW�p�&<�g����i�>=�3�����4�
# �EJ���}=�����k(=|��<Z׼6�F��M
# =bͩ=�.=����0��!��=A���,����ʕ;�w}����;���=�@�<B�o=OzM�r�{���I=��Լ,C�<�$=�3=╽�:��K���*˄��ة=6X��R�Y=�7���q:��>�v�;}�6��E<B�<=Tϼ��N=׳	=Tە� [�<*l�=#z�<m��=8��=���=I2����>p;KG�=P["�uuC=�8��==[ �����y�������n/�L�Q<;Iy<�V����������K����u:�D��k2=k^���>=͞��.�;��=�i�=�;J=��E=��>U�<�G=b�r=��<���	�t8=E�<��>����+=#��oث=g���)/���W�9@�ȼ�X�;N�w=�ⒼI��==���i=���=��d��5e�=����H�gbh����������c���*��ˤ�=}�4=6\b=����ׄ��d���[�;�_�<��}[=Y�=k\�=��=L�Ǽ��6���6=�"T�>XX��4�=N���6��j\���=��5Ƚ��= "%=�Q=�#Y=��<��d<^&��@ܽe��=�ʑ���
# $<�9=1	��ɽP?�ι=�ڦ=P
# ���8�YZ�<�%7�{ޡ��ͽ=���?Ѳ3��U�;��ɽ]=��=!��=��=�Y�=b��=���=0N�Q�d=���.���\}ȾU��=��G�kl=��|=�զ���=�g�<�[�w���Ш=P��p�z<y�u<��:���*�=h�4�J��=�oO���(=3�!��Ɋ��{q<�l�=5�ʽk�<}�f=ì�<泫��k�_�v�`&�<�>�]�=��>�gG=����-@=�U
# m�<�̽c��=P�=�����g�?D�
# �������<��<=��
# ��y۾V�==03߻��'���ؼ��+�=�{�=�v=�^Ⱦ,I= (ػ���==�o>�='��<i�=
# m�<!�<�����<WbR=rp=0�(�9Ώ=.H�;
# �=�?�=� �=g���Fnl=���;
# ����?ZF׼G �W��=���>�Ӟ��cS3�施x���=B�uG��F��&�;=h�o���o���6=��#�ਕ;Um��j%=��"�΁���쏽�r�ڜ ����驵=+��4��ZkR��:7����;��ʶ.��N��Xq!<�zR�|ަ�R��[?�=�~6����d��뭥����=!��=��[=vݽ�j;@�,랽w�W���@�O�<�)4�Ʀ��=n�������0�(8��T:�`������<9)�=�1��/%�����=z�1�i<��?��	�~��@�x�����нb����=���;�"���]E����ͦ˽\T�n!�k�s��5�y���5�=陳���u���k���/�b	�ߦ�=������%=�~�=��H��C@=V�?����@�=`��;��V��&˽`���Җ=v���L�f=I:�
#  �=�ό=��z=�v�=�ٳ��Z��tU���r��ʉ��Z|��"3�=��<='F��I�L��=,Ϸ�0�l<��,��m���=�寽�q�s0�<�`I=;�9�-��=<P�=��K���˼j��=�T�=�͵�`H;��=���=I
# E��aQ�lW�����=�Ϝ=���[ټǖr���?=��b���]=ԉھH
# �=W��= �d�tٿ=�}{<FJ��M�=3
# r��;�=Q���Ʋ��a��C����Ӛ=B��=�@';X��=���;�ʟ�QD���Ɛ�筽�Ȧ���'�,�[<ȱѼ�
# �%K�=o���NF�΂���sW����}Ȏ;�<�[�;�{�u���t��������=$3�<JEM=d��j���
# �(a�;4舽�"=�g)=w��CJJ>~А�+d�=��=�f�����6�<*�b=��=���>Hj��a��=����Ž��/<w�ɺ&�A=-�[�J�����=n施�
# �!���/h�+.;@l�<�8�<dpϼ�l���=�M=�����j=^�����Pk���V�����;���<�I�<ʸ�^�t��U����Z>�
# ɦ<&2q=��s�T)���ƚ�=D�Θ�=��~�l���T =����AY=m-����<@����h���
# ٰ��P�=��=d�o�3[�ʰS=��鼁����� ���c��c�eT�=S7y����)�=�/��<d�� ���.p���g�=�Ĳ��T<ꝼ;��;+M�io�=X�<�S�=��=fF��U�� ����ǽ
# �=U�=�ߢ�2�<�@&�G[�	<,<�ɽ=�= 6�;Yx+?���<��ҿӂ:�l�����=��<����=�"���{�$�k<j�(�
# �5V��Y�<���<�g=�h��������
# �?�23<�O=}9��[��;�K�?�;]
# 5�2%=lB=̾.<��H���	�Y�q���=t�X���x����<n�+<����Ɔ=�ݖ������=h>{�#u�=׫��iT=SR��4]=g^߽�u�=2����
# ��=��ξ@/W<{�=���hT�=�P!=6S+����<�錽8�����=B�=G�=����zz<L�ֺ;cj�nN=$��==l#<��=(K��}��=����`,�ʟ}��/�=���o�6��+�����Ҽ�}���==�Y�=$�=V�=�(��P
# ��{=����s�=*P%���R���
# �j"?���`��?HhǼ��8=!���kJ�;Q��<𸡽BeS=vv�=ĭ��T_��]G=���=�:�<�����]�=��?�ק�<�RX��e�����Ώ�����m����=ݨ>��/;�x��<�N�7kٽ�Q���b
# =F+�<xF =z���<ز�<�U�<	H�=4�<eê��&�����Ǝ=hq�<�l=���=3w���<"=��=τܽ������	�Ľ�pX=�����A��7�<nw[=���zN@=�B��ݲ:�c�@��嶽`a�;@�0������=���<]ҼI�=�V���ô�>��<C�=������|=�N/=(�<#P�=يԽB�ڼ�h�=���<��<Qws<~|��6�㽺���*��D����c?_��=iμ�z����<�|l=�>{=3�U=v=ң8�H듽��d�ǫj���=0�E���;�%�6=�Ӻ�H�=��z�_��=,}l<�mh���=}�1>�U�=�:�=h�߼�Xa=؜��<��=.ѳ�
# IŽ��=x1t=�+p��ؓ:jt<�y3=��9y���韽X�<�d������=N|=���<DȚ?v�=FY=¡[=>�=���=��=Z=ݼ�=6b?�a=6}�~C����[=j�v�H6�<��֝�=�.�=��=4��<�k�
# ��Е⻢I=R�?�X�Y<�v�=3�����X����v��ꄽ[�=z� =f��=?��=�^��h��;��<=V����½�J=��=��=�mZ�M�=ߨ�� Zݼ����bJ���5�*E���`�=S<�f�y���/=fᇽzv=F�ּ��I=d�<�]4�"��g�?�L��=�����
# �(V<ۓ��0����T��3���B����8G?�􈽙����Z�<���<y�B�*3��<�<��ڔȽ&�U��==��D���.�A��<|��:�lo��iE�|C���=���=�pj��Ia=ʬ����mܻ-Om=v�f=�ԯ=Q��5{i�`��=Y���h���\<��g��=�$2�	v�=qu�UX�� k��ΦK�a����	S�ϡ��7��>���������/a�tz�<������~��
# ��=s&�=�y-�lZƽ�,�=�̺�qP7=萉��|Ƽ[�˽�3N=���;Τ;O�=�b�=�҃�J���<L쾽�A����W;����Q�=�;=��G���=;1s�=�Dl=����n��A�`�<��=B��y�=Ͻv伮�@;��=�l%������M����Á;���ˎ{=�?B=���=(����=胀=�bo��;X:i�#=;�1���O<f�=:�}J=�
# �Ҽ>@!)=Tؼ�<��=�g��=��˽(�P=��0�2"�<��<���<,î�#	3=��=���=�����o=һ����=7���k*�!��=�LG=���=T��<�?�<S�=�n=H/���ν-��,bؼM�o�D*�<�z��nl=]�@<@�=��}=��ϼ��<�3=�͟��-ͽ=5G�v�>�N�<��@��=�ݽ�c&�<Q���Ò������pI=>�@=Խ�ռ
# ��a追���^��<�=��P�$<
# e��u�;ߏ5�f.޼��=2���ı<���-����#P�b:l<��D?��9�(��ۯ=IE���w�=�Z��gZ=*ED��W��� =V�ͻ�d�9G�="D�<ѺǾ�2�=�c=V����K������m�o�p���Y0y�������a=���=ב�=8�!����:*��=
# =��=i��<�ӥ�<��=���=`�����=���W,�_��=Ŵ���έ��i�<Vi,��NT=|j���Cz��r�@=Z���L �<�W!����C<���=nX*������=�1>=��I=sia�}�l=���=�Z�:,d����輀�Z�
# #�=�^��զ����=��=Z�}=��=�y�<�T���]���=9W�=V7��.��<�6M��֗��] =
# ��H8J=�����=�=N�=�p=wI����F���5=���7r^�=꫽�=<�߂��lX�"k�=핱;�m���(˼�=dhr=���뼼����R�<�}��]�=Ч�;
# �.��o�=��=�l½w��<E!��m���l^��e�='�=�v�=�u`���j��HC=4/�<a!�=H[���������>���:S'�>~(��$���B=�Ȑ<������Im�=(��<D��<�g="�+=v�!����=�V=G����+�:��=Z�:=t;�� -��9<��Z<d�~�;�AĽ��=�B�<f򅼂fK���@�G+��p"=�8j=�K�<S�<FV=\=�ϔ=�@�=��=!�E=�g
# 1�=�=�ܒ��&̽�c\�M,<w�u=��=�W����\=�½3��=C�x���$��W8=�L��6\*���I=�8ϼ�$�=��=F����=�ݷ���?<�7��,5�pW=��<ce�=�^�<�:�,,����=/:\~=�%�
# &>/�����
# >�L�������>�i����Y>�M/�Y��=�C�>��F>��u�.}�>�� �7yǾK��>NK;X �>�)C��ӧ>a�$>�[>�4�����>m����ē>o��=�������Ų?�>汾�>��+���=j�n�V�>���ϱ_����C�=Ѿ�j$����>��������^X��z��>5?N>Ϧ>���ۦ�P�i��U<� \��*�^��r>�C��u�=$�i>cDѾԇ����ʎ;q����J�>�
# 4]?Q�*�c1���]?��о��]?��>m�>+����Q��''���]��M���B>5QǾs�O>�����>�0����S=�ܾ/�#>[�꽕����8����m��Z�7>u��>Z��>�΋��`G���!>�X?C�4<��.?<w0��)>��H>,-�>�X��g���m>�&9?�
# h>�.�>'�g9-$E?�?K���U\?�q@6��Y��%R�=Q!5��	>��>�&?p<�����>&S���e>%�>E>y.s��Nb>�;���>�Nd�FQd��;s�{�ǽ$�]?�d�9���C��>�Vn�\��=Rhy��ء�Nߎ>ҲX�XEd>��h=D��G;�= �"?bD��^?���c>U��y;�q^=>�?G?���/�����;Y�

# %% [markdown]
# ## Loading Model
# * We saved the entire model and not the state dict. Loading requires the class definition to be in the same script as well.
# * **Compute the accuracy, precision and recall from the loaded model**

# %%
new_model = torch.load('models/classifier.pt')

# %%
predict_out = new_model(Xtest_)
_, predict_y = torch.max(predict_out, 1)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print ('prediction accuracy', accuracy_score(Ytest_.data, predict_y.data))
print ('micro precision', precision_score(Ytest_.data, predict_y.data, average='micro'))
print ('micro recall', recall_score(Ytest_.data, predict_y.data, average='micro'))
# Out:
# prediction accuracy 0.9305555555555556
# micro precision 0.9305555555555556
# micro recall 0.9305555555555556
