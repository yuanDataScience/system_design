# %% [markdown]
# # Parallelize the training of a PyTorch model across processors and machines

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

import torch
from torch import nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split

# %%
torch.cuda.device_count()
# Out:
# 2

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
wine_data = pd.read_csv('wine_data.csv')
wine_features = wine_data.drop('Class', axis = 1)
wine_target = wine_data[['Class']]

# %%
X_train, x_test, Y_train, y_test = train_test_split(wine_features,
                                                    wine_target,
                                                    test_size=0.4,
                                                    random_state=0)

# %%
Xtrain_ = torch.from_numpy(X_train.values).float()
Xtest_ = torch.from_numpy(x_test.values).float()

Ytrain_ = torch.from_numpy(Y_train.values).view(1,-1)[0]
Ytest_ = torch.from_numpy(y_test.values).view(1,-1)[0]

# %%
Xtrain_ = Xtrain_.to(device)
Ytrain_ = Ytrain_.to(device)
Xtest_ = Xtest_.to(device)
Ytest_ = Ytest_.to(device)

# %%
input_size = 13
output_size = 3
hidden_size = 100

# %%
class Net(nn.Module):
    
    def __init__(self):
        
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, output_size)

    def forward(self, X):
        
        X = torch.sigmoid((self.fc1(X)))
        X = torch.sigmoid(self.fc2(X))
        X = self.fc3(X)
        
        print("\nInside  the model: Device id - ", torch.cuda.current_device())

        return F.log_softmax(X, dim=-1)

# %% [markdown]
# ## nn.DataParallel
#
#
#
# * First, we need to make a model instance and check if we have multiple GPUs. If we have multiple GPUs, we can wrap our model using nn.DataParallel. Then we can put our model on GPUs by model.to(device)
#
# * We’ve placed a print statement inside the model to monitor the size of input and output tensors.
#
# *  just calling my_tensor.to(device) returns a new copy of my_tensor on GPU instead of rewriting my_tensor. You need to assign it to a new tensor and use that tensor on the GPU.
#
# * It’s natural to execute your forward, backward propagations on multiple GPUs. However, Pytorch will only use one GPU by default. You can easily run your operations on multiple GPUs by making your model run parallelly using DataParallel
#
# * DataParallel parallelizes the application of the given :attr:`module` by
#     splitting the input across the specified devices by chunking in the batch
#     dimension (other objects will be copied once per device). In the forward
#     pass, the module is replicated on each device, and each replica handles a
#     portion of the input. During the backwards pass, gradients from each replica
#     are summed into the original module.

# %%
model = Net()
    
model = nn.DataParallel(model)

model.to(device)
# Out:
# DataParallel(
#   (module): Net(
#     (fc1): Linear(in_features=13, out_features=100, bias=True)
#     (fc2): Linear(in_features=100, out_features=100, bias=True)
#     (fc3): Linear(in_features=100, out_features=3, bias=True)
#   )
# )

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

loss_fn = nn.NLLLoss()

# %%
epochs = 100

for epoch in range(epochs):

    optimizer.zero_grad()
    
    Ypred = model(Xtrain_)
    loss = loss_fn(Ypred, Ytrain_ )
    
    loss.backward()
    optimizer.step()
        
    print("\nOutside the model: Device id - %d, Loss - %f" %(torch.cuda.current_device(), loss.item()))
# Out:
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.646588
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.643560
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.640521
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.637470
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.634518
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.631801
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.629254
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.626631
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.623873
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.621140
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.618529
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.616003
#
# Inside  the model: Device id -
# Inside  the model: Device id -  0
#  1
#
# Outside the model: Device id - 0, Loss - 0.613508
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.611042
#
# Inside  the model: Device id -  0
# Inside  the model: Device id -
#  1
#
# Outside the model: Device id - 0, Loss - 0.608630
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.606228
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.603783
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.601344
#
# Inside  the model: Device id -
# Inside  the model: Device id - 0
#  1
#
# Outside the model: Device id - 0, Loss - 0.598985
#
# Inside  the model: Device id -  0
# Inside  the model: Device id -  1
#
#
# Outside the model: Device id - 0, Loss - 0.596671
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.594313
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.591891
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.589443
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.586992
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.584546
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.582110
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.579617
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.576831
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.573619
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.570171
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.566858
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.563940
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.561425
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.558713
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.555793
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.552803
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.549665
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.546426
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.543264
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.540339
#
# Inside  the model: Device id -  0
# Inside  the model: Device id -  1
#
#
# Outside the model: Device id - 0, Loss - 0.537639
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.534504
#
# Inside  the model: Device id -
# Inside  the model: Device id -  0
# 1
#
# Outside the model: Device id - 0, Loss - 0.531207
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.527873
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.524598
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.521444
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.518269
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.515180
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.511883
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.508382
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.504982
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.501659
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.498387
#
# Inside  the model: Device id -
# Inside  the model: Device id -  0
#  1
#
# Outside the model: Device id - 0, Loss - 0.494974
#
# Inside  the model: Device id -
# Inside  the model: Device id -  1
#  0
#
# Outside the model: Device id - 0, Loss - 0.491474
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.487936
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.484333
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.480691
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.476874
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.472038
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.466512
#
# Inside  the model: Device id -
# Inside  the model: Device id -  1
#  0
#
# Outside the model: Device id - 0, Loss - 0.463819
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.460492
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.456106
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.451795
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.448501
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.444851
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.440686
#
# Inside  the model: Device id -
# Inside  the model: Device id -  1
# 0
#
# Outside the model: Device id - 0, Loss - 0.436448
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.432720
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.428896
#
# Inside  the model: Device id -
# Inside  the model: Device id -   1
# 0
#
# Outside the model: Device id - 0, Loss - 0.424944
#
# Inside  the model: Device id -
# Inside  the model: Device id -  1
#  0
#
# Outside the model: Device id - 0, Loss - 0.420771
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.416871
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.412867
#
# Inside  the model: Device id -
# Inside  the model: Device id -  0
# 1
#
# Outside the model: Device id - 0, Loss - 0.408870
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.404844
#
# Inside  the model: Device id -
# Inside  the model: Device id -  1
#  0
#
# Outside the model: Device id - 0, Loss - 0.401011
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.397079
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.393145
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.388912
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.384799
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.380847
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.377042
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.372955
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.368877
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.365001
#
# Inside  the model: Device id -
# Inside  the model: Device id -  0
#  1
#
# Outside the model: Device id - 0, Loss - 0.361153
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.357184
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.353181
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.349381
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.345568
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.341712
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.337837
#
# Inside  the model: Device id -
# Inside  the model: Device id -   1
# 0
#
# Outside the model: Device id - 0, Loss - 0.334074
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.330344
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.326601
#
# Inside  the model: Device id -  1
#
# Inside  the model: Device id -  0
#
# Outside the model: Device id - 0, Loss - 0.322848
#
# Inside  the model: Device id -
# Inside  the model: Device id -  1
#  0
#
# Outside the model: Device id - 0, Loss - 0.319150
#
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1
#
# Outside the model: Device id - 0, Loss - 0.315518

# %%
predict_out = model(Xtest_)
_, predict_y = torch.max(predict_out, 1)
# Out:
# Inside  the model: Device id -  0
#
# Inside  the model: Device id -  1

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

print ('prediction accuracy', accuracy_score(Ytest_.cpu().data, predict_y.cpu().data))
print ('micro precision', precision_score(Ytest_.cpu().data, predict_y.cpu().data, average='micro'))
print ('micro recall', recall_score(Ytest_.cpu().data, predict_y.cpu().data, average='micro'))
# Out:
# prediction accuracy 0.9583333333333334
# micro precision 0.9583333333333334
# micro recall 0.9583333333333334
